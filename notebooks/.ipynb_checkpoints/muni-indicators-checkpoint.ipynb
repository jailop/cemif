# %% [markdown]
# # Indicadores de finanzas municipales

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Definiciones y carga de datos

# %%
keys = [
    {"key": "INGPRP", "label" : "A. Ingresos propios", "category": "revenue"},
    {"key": "ICTESP", "label" : "B. Ingresos por contribuciones especiales", "category": "revenue"},
    {"key": "TRFREC", "label" : "C. Transferencias recibidas", "category": "revenue"},
    {"key": "INGDEU", "label" : "D. Endeudamiento", "category": "revenue"},
    {"key": "GASTOS", "label" : "A. Gastos", "category": "expenses"},
    {"key": "INVERS", "label" : "B. Inversiones", "category": "expenses"},
    {"key": "AMTDEU", "label" : "C. Amortización de deudas", "category": "expenses"},
    {"key": "EGROTR", "label" : "D. Otros egresos", "category": "expenses"},
    {"key": "FDINVF", "label" : "A. Fondos e inversiones financieras", "category": "assets"},
    {"key": "EXISBU", "label" : "B. Existencias y bienes de uso", "category": "assets"},
    {"key": "INVPRY", "label" : "C. Inversiones en proyectos", "category": "assets"},
    {"key": "RECOTR", "label" : "D. Otros recursos", "category": "assets"},
    {"key": "OBLGCP", "label" : "A. Obligaciones de corto plazo", "category": "obligations"},
    {"key": "OBLGLP", "label" : "B. Obligciones de largo plazo", "category": "obligations"},
    {"key": "GTOING", "label" : "Razón entre gastos e ingresos propios", "category": "ratio"},
    {"key": "INVGTO", "label" : "Razón entre inversión y gastos", "category": "ratio"},
    {"key": "DEUING", "label" : "Razón entre deuda e ingresos propios", "category": "ratio"},
    {"key": "DEPTRF", "label" : "Dependencia de las transferencias", "category": "ratio"},
    {"key": "DEPDEU", "label" : "Dependencia del endeudamiento", "category": "ratio"}
]

# %%
dataPath = "../client/data/"
budget = pd.read_csv(dataPath + "mun-budget-year-header.csv")
contab = pd.read_csv(dataPath + "mun-contab-year-header.csv")
len(budget), len(contab)
# Out:
# (120816, 81550)

# %%
budget.head()
# Out:
#    year  muni_contab_id  object class        amount
# 0  2010            8101      11   ACR  1.007948e+06
# 1  2010            8101      11   APR  1.191000e+06
# 2  2010            8101      11   MOD  1.191000e+06
# 3  2010            8101      12   ACR  1.519010e+06
# 4  2010            8101      12   APR  1.599400e+06

# %%
contab.head()
# Out:
#    year  muni_contab_id  account        amount
# 0  2010            8101      211  6.143657e+05
# 1  2010            8101      212  3.498976e+04
# 2  2010            8101      213  5.788516e+05
# 3  2010            8101      222  4.721059e+04
# 4  2010            8101      225  2.575379e+06

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Agrupación presupuestaria
#
# Los egresos se agrupan en las siguientes categorías:
#
# - Gastos
# - Inversiones
# - Amortización de deudas
#
# Los ingresos se agrupan en:
#
# - Ingresos propios
# - Contribuciones especiales
# - Transferencias recibidas
# - Endeudamiento

# %%
def groupBudget(obj):
    if obj >= 50:
        kind = "Egresos"
        if obj >= 50 and obj < 60:
            return kind, "GASTOS"
        elif obj >= 60 and obj < 70:
            return kind, "INVERS"
        elif obj >= 70 and obj < 80:
            return kind, "AMTDEU"
        else:
            return kind, "EGROTR"
    else:
        kind = "Ingresos"
        if obj == 16 or obj == 22:
            return kind, "TRFREC"
        elif obj == 31:
            return kind, "INGDEU"
        elif obj == 41:
            return kind, "ICTESP"
        else:
            return kind, "INGPRP"

# %%
for i in range(len(budget)):
    rec = budget.iloc[i]
    kind, group = groupBudget(rec["object"])
    budget.at[i, "kind"] = kind
    budget.at[i, "group"] = group

# %%
budgetGrouped = budget.groupby(["year", "muni_contab_id", "class", "kind", "group"])\
    .sum()["amount"].reset_index()
budgetGrouped.head()
# Out:
#    year  muni_contab_id class      kind   group        amount
# 0  2010            8101   ACR   Egresos  AMTDEU  1.748385e+05
# 1  2010            8101   ACR   Egresos  GASTOS  3.472434e+06
# 2  2010            8101   ACR   Egresos  INVERS  2.099882e+06
# 3  2010            8101   ACR  Ingresos  INGDEU  1.000000e+05
# 4  2010            8101   ACR  Ingresos  INGPRP  2.730930e+06

# %%
budgetGrouped.rename(columns={"muni_contab_id": "contab"}, inplace=True)

# %% [markdown]
# ### Agrupación contable
#
# Los recursos se agrupan en:
#
# - Fondos e inversiones financieras
# - Existencias y bienes de uso
# - Inversiones en proyectos
#
# Las obligaciones se agrupan en:
#
# - Obligaciones de corto plazo
# - Deuda de largo plazo

# %%
def groupContab(acc):
    acc = str(acc)
    if acc >= "200" and acc < "400":
        kind = "Recursos"
        acc = acc[:2]
        if acc == "21" or acc == "22":
            return kind, "FDINVF"
        elif acc == "23" or acc == "24":
            return kind, "EXISBU"
        elif acc == "25":
            return kind, "INVPRY"
        else:
            return kind, "RECOTR"
    else:
        kind = "Obligaciones"
        acc = acc[:2]
        if acc == "41":
            return kind, "OBLGCP"
        else:
            return kind, "OBLGLP"

# %%
for i in range(len(contab)):
    rec = contab.iloc[i]
    kind, group = groupContab(rec["account"])
    contab.at[i, "kind"] = kind
    contab.at[i, "group"] = group

# %%
contabGrouped = contab.groupby(["year", "muni_contab_id", "kind", "group"]).sum()["amount"].reset_index()
contabGrouped.head()
# Out:
#    year  muni_contab_id          kind   group        amount
# 0  2010            8101  Obligaciones  OBLGCP  2.172875e+05
# 1  2010            8101  Obligaciones  OBLGLP  3.311050e+07
# 2  2010            8101      Recursos  EXISBU  1.785698e+07
# 3  2010            8101      Recursos  FDINVF  3.865648e+06
# 4  2010            8101      Recursos  INVPRY  5.890917e+04

# %%
contabGrouped.rename(columns={"muni_contab_id": "contab"}, inplace=True)

# %% [markdown]
# ## Cálculo de indicadores

# %%
# Data structure to save indicators datasets

indicadators = {}
df = pd.concat([
    budgetGrouped[budgetGrouped["class"] == "ACR"],
    contabGrouped
])
df = df.pivot(
    index=["year", "contab"],
    columns="group",
    values="amount"
).reset_index()

# %%
df.columns
# Out:
# Index(['year', 'contab', 'AMTDEU', 'EGROTR', 'EXISBU', 'FDINVF', 'GASTOS',
#        'ICTESP', 'INGDEU', 'INGPRP', 'INVERS', 'INVPRY', 'OBLGCP', 'OBLGLP',
#        'TRFREC'],
#       dtype='object', name='group')

# %%
def plotIndicator(df, key, log=False):
    for year in df.year.unique():
        sub = df[df["year"] == year]
        y = sub[key].values
        if log:
            y = np.log10(y[y != 0])
        plt.plot(range(len(y)), np.sort(y))

# %% [markdown]
# ### Relación entre gastos e ingresos propios

# %%
key = "GTOING"
df[key] = df["GASTOS"] / df["INGPRP"]
plotIndicator(df, key, log=True)

# %% [markdown]
# ### Relación entre inversión y gastos

# %%
key = "INVGTO"
df[key] = df["INVERS"] / df["GASTOS"]
plotIndicator(df, key)

# %% [markdown]
# ### Relación entre deuda e ingresos propios

# %%
key = "DEUING"
df[key] = df["OBLGLP"] / df["INGPRP"]
plotIndicator(df, key)

# %% [markdown]
# ### Dependencia de las transferencias

# %%
key = "DEPTRF"
df[key] = df["TRFREC"] / (df["GASTOS"] + df["INVERS"])
plotIndicator(df, key, log=True)

# %% [markdown]
# ### Dependencia del endeudamiento

# %%
key = "DEPDEU"
df[key] = (df["INGDEU"] - df["AMTDEU"]) /  (df["GASTOS"] + df["INVERS"])
plotIndicator(df, key)

# %% [markdown]
# ### Agregando otras variables

# %%
population = pd.read_csv("../data/supl/population.csv")
population.head()
# Out:
#    municipality  year     source attribute     value
# 0           101  2007  censo2007   urb_hom  144217.0
# 1           102  2007  censo2007   urb_hom   52381.0
# 2           103  2007  censo2007   urb_hom   64509.0
# 3           104  2007  censo2007   urb_hom  111234.0
# 4           105  2007  censo2007   urb_hom   30782.0

# %%
population.attribute.unique()
# Out:
# array(['urb_hom', 'urb_muj', 'rur_hom', 'rur_muj', 'popurb', 'masc',
#        'depend', 'sixtyeqgreater', 'tgf', 'tmi', 'analf', 'asistesc',
#        'water', 'electricity', 'notoilet', 'dirtfloor'], dtype=object)

# %%
popTotal = pd.concat([
    population[population.attribute == "urb_hom"],
    population[population.attribute == "urb_muj"],
    population[population.attribute == "rur_hom"],
    population[population.attribute == "rur_muj"],
])
popTotal = popTotal.groupby("municipality").sum()["value"].reset_index()
popTotal.rename(columns={"municipality": "id", "value": "population"}, inplace=True)
popTotal.head()
# Out:
#     id  population
# 0  101    316090.0
# 1  102    120200.0
# 2  103    140751.0
# 3  104    241403.0
# 4  105     66400.0

# %%
municipalities = pd.read_json("http://localhost:8080/api/v2/municipalities")
municipalities.head()
# Out:
#      id  shp  contab    department   municipality  \
# 0   603  227    8301     Sonsonate       Acajutla
# 1   910   22    8401  Chalatenango  Agua Caliente
# 2   112  179    8601  San Salvador      Aguilares
# 3  1101    1    8101    Ahuachapán     Ahuachapán
# 4   512  243    9101      Usulután        Alegría
#
#                                              address  \
# 0                  Calle Principal, Barrio Las Peñas
# 1   1a Avenida Norte Barrio El Centro, Agua Caliente
# 2              Costado Poniente del parque municipal
# 3  3a. Calle Pte. y 2a Av. Sur, frente al parque ...
# 4         Barrio El Centro frente a parque municipal
#
#                                phone email url     km2
# 0    2429-7300\n2429-7327\n2429-7331            166.59
# 1                          2309-7700            195.74
# 2                          2327-5100             33.72
# 3                          2487-4800            244.84
# 4  2668-5600 \n2668-5602 \n2628-1143             40.41

# %%
df = df.merge(
    municipalities[["id", "shp", "contab", "department", "municipality"]], 
    on="contab"
)
df = df.merge(popTotal, on="id")
df
# Out:
#       year  contab        AMTDEU  EGROTR        EXISBU        FDINVF  \
# 0     2010    8101  1.748385e+05     NaN  1.785698e+07  3.865648e+06
# 1     2011    8101  1.075870e+06     NaN  1.784860e+07  4.384201e+06
# 2     2012    8101  1.100014e+05     NaN  1.814108e+07  4.291781e+06
# 3     2013    8101  2.266375e+05     NaN  1.382478e+07  6.604323e+06
# 4     2014    8101  2.619902e+05     NaN  1.648256e+07  6.130096e+06
# ...    ...     ...           ...     ...           ...           ...
# 2959  2016    9418  7.914547e+04     NaN  2.946028e+05  7.356175e+05
# 2960  2017    9418  9.489671e+04     NaN  2.864100e+05  4.174067e+05
# 2961  2018    9418  1.043895e+05     NaN  3.042648e+05  2.084495e+05
# 2962  2019    9418           NaN     NaN  2.960940e+05  4.072852e+05
# 2963  2020    9418  1.730040e+06     NaN  2.868987e+05  1.260929e+06
#
#             GASTOS  ICTESP        INGDEU        INGPRP  ...    GTOING  \
# 0     3.472434e+06     NaN  1.000000e+05  2.730930e+06  ...  1.271520
# 1     3.836138e+06     NaN  1.122255e+06  2.841217e+06  ...  1.350174
# 2     4.020159e+06     NaN  2.564927e+05  2.944718e+06  ...  1.365210
# 3     4.453212e+06     NaN  7.435073e+05  3.803865e+06  ...  1.170707
# 4     4.549759e+06     NaN  8.810233e+05  3.872705e+06  ...  1.174827
# ...            ...     ...           ...           ...  ...       ...
# 2959  5.933959e+05     NaN  3.250000e+05  1.350516e+05  ...  4.393845
# 2960  8.957238e+05     NaN           NaN  1.266270e+05  ...  7.073719
# 2961  7.206439e+05     NaN           NaN  9.918722e+04  ...  7.265491
# 2962           NaN     NaN           NaN  2.002816e+06  ...       NaN
# 2963  1.025445e+06     NaN  2.152000e+06  1.131275e+05  ...  9.064506
#
#         INVGTO      DEUING    DEPTRF    DEPDEU    id  shp  department  \
# 0     0.604729   12.124257  0.512006 -0.013430  1101    1  Ahuachapán
# 1     0.447227   11.845201  0.448979  0.008355  1101    1  Ahuachapán
# 2     0.538954   12.997602  0.432135  0.023678  1101    1  Ahuachapán
# 3     0.634743   11.900664  0.434734  0.071000  1101    1  Ahuachapán
# 4     0.712124   10.236684  0.402469  0.079468  1101    1  Ahuachapán
# ...        ...         ...       ...       ...   ...  ...         ...
# 2959  0.704460   36.610163  1.097674  0.243079   710  132    La Unión
# 2960  0.558361   48.991731  0.759228       NaN   710  132    La Unión
# 2961  0.806611   52.467222  0.819745       NaN   710  132    La Unión
# 2962       NaN    2.118282       NaN       NaN   710  132    La Unión
# 2963  0.948331  159.430914  1.082300  0.211201   710  132    La Unión
#
#       municipality  population
# 0       Ahuachapán    110511.0
# 1       Ahuachapán    110511.0
# 2       Ahuachapán    110511.0
# 3       Ahuachapán    110511.0
# 4       Ahuachapán    110511.0
# ...            ...         ...
# 2959    Yucuaiquín      6799.0
# 2960    Yucuaiquín      6799.0
# 2961    Yucuaiquín      6799.0
# 2962    Yucuaiquín      6799.0
# 2963    Yucuaiquín      6799.0
#
# [2964 rows x 25 columns]

# %% [markdown]
# ### Salvando los indicadores

# %%
df.head()
# Out:
#    year  contab        AMTDEU  EGROTR        EXISBU        FDINVF  \
# 0  2010    8101  1.748385e+05     NaN  1.785698e+07  3.865648e+06
# 1  2011    8101  1.075870e+06     NaN  1.784860e+07  4.384201e+06
# 2  2012    8101  1.100014e+05     NaN  1.814108e+07  4.291781e+06
# 3  2013    8101  2.266375e+05     NaN  1.382478e+07  6.604323e+06
# 4  2014    8101  2.619902e+05     NaN  1.648256e+07  6.130096e+06
#
#          GASTOS  ICTESP        INGDEU        INGPRP  ...    GTOING    INVGTO  \
# 0  3.472434e+06     NaN  1.000000e+05  2.730930e+06  ...  1.271520  0.604729
# 1  3.836138e+06     NaN  1.122255e+06  2.841217e+06  ...  1.350174  0.447227
# 2  4.020159e+06     NaN  2.564927e+05  2.944718e+06  ...  1.365210  0.538954
# 3  4.453212e+06     NaN  7.435073e+05  3.803865e+06  ...  1.170707  0.634743
# 4  4.549759e+06     NaN  8.810233e+05  3.872705e+06  ...  1.174827  0.712124
#
#       DEUING    DEPTRF    DEPDEU    id  shp  department  municipality  \
# 0  12.124257  0.512006 -0.013430  1101    1  Ahuachapán    Ahuachapán
# 1  11.845201  0.448979  0.008355  1101    1  Ahuachapán    Ahuachapán
# 2  12.997602  0.432135  0.023678  1101    1  Ahuachapán    Ahuachapán
# 3  11.900664  0.434734  0.071000  1101    1  Ahuachapán    Ahuachapán
# 4  10.236684  0.402469  0.079468  1101    1  Ahuachapán    Ahuachapán
#
#    population
# 0    110511.0
# 1    110511.0
# 2    110511.0
# 3    110511.0
# 4    110511.0
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['year', 'contab', 'AMTDEU', 'EGROTR', 'EXISBU', 'FDINVF', 'GASTOS',
#        'ICTESP', 'INGDEU', 'INGPRP', 'INVERS', 'INVPRY', 'OBLGCP', 'OBLGLP',
#        'TRFREC', 'GTOING', 'INVGTO', 'DEUING', 'DEPTRF', 'DEPDEU', 'id', 'shp',
#        'department', 'municipality', 'population'],
#       dtype='object')

# %%
out = df.melt(
    id_vars=["year", "id", "shp", "contab", "department", "municipality", "population"],
    value_vars=['AMTDEU', 'EGROTR', 'EXISBU', 'FDINVF', 'GASTOS',
       'ICTESP', 'INGDEU', 'INGPRP', 'INVERS', 'INVPRY', 'OBLGCP', 'OBLGLP',
       'TRFREC', 'GTOING', 'INVGTO', 'DEUING', 'DEPTRF', 'DEPDEU'],
    var_name="group", 
    value_name="value"
)
out["id"] = out["id"].apply(lambda v: str(v).zfill(4))

# %%
out = out[out["value"].isna() == False]
len(out)
# Out:
# 42725

# %%
out.to_csv(dataPath + "muni-indicators.csv", index=False)

# %%
pd.DataFrame(keys).to_csv(dataPath + "muni-indicators-keys.csv", index=False)
